# %%
import xml.etree.ElementTree as etree
import codecs
import csv
import time
import os
import re
import gzip

# %%
PATH_WIKI_XML = 'd:/MMD- Project - Power2TheWiki/data/en/'
PATH_WIKI_OUT = 'd:/MGontar/Storages/Google Drive/20. Data Science/0.UCU Study/Mining Massive Datasets/Project/out/'

# %%
WIKI_FILENAMES = []
for file in os.listdir(PATH_WIKI_XML):
    if file.endswith(".xml"):
        WIKI_FILENAMES.append(file)

# %%
ENCODING = "utf-8"

# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)


def strip_tag_name(t):
    t = elem.tag
    idx = k = t.rfind("}")
    if idx != -1:
        t = t[idx + 1:]
    return t


totalCount = 0
articleCount = 0
redirectCount = 0
total_article_text_len = 0

# %%
start_time = time.time()
regex_links = re.compile(r"\[\[(?P<article>(?!.*?\:).*?)(?:\|(?P<text>(?!.*?\:).*?))?\]\]")
regex_lang = re.compile(r"\[\[uk\:(?P<article>.+?)\]\]")
regex_lang_ru = re.compile(r"\[\[ru\:(?P<article>.+?)\]\]")
for WikiXML in WIKI_FILENAMES:
    pathWikiXML = os.path.join(PATH_WIKI_XML, WikiXML)
    pathArticles = os.path.join(PATH_WIKI_OUT, WikiXML+"_art.csv")
    pathArticlesRedirect = os.path.join(PATH_WIKI_OUT, WikiXML+"_red.csv")
    with codecs.open(pathArticles, "w", ENCODING) as articlesFH, \
    codecs.open(pathArticlesRedirect, "w", ENCODING) as redirectFH:
        articlesWriter = csv.writer(articlesFH, quoting=csv.QUOTE_MINIMAL)
        articlesWriter.writerow(['id', 'title', 'text_len', 'link_pos', 'link_val', 'link_txt']) 
        redirectWriter = csv.writer(redirectFH, quoting=csv.QUOTE_MINIMAL)
        redirectWriter.writerow(['id', 'title', 'redirect'])
        for event, elem in etree.iterparse(pathWikiXML, events=('start', 'end')):
            tname = strip_tag_name(elem.tag)

            if event == 'start':
                if tname == 'page':
                    title = ''
                    id = -1
                    redirect = ''
                    inrevision = False
                    ns = 0
                    article_text_len = 0
                    links = []
                elif tname == 'revision':
                    # Do not pick up on revision id's
                    inrevision = True
            else:
                if tname == 'title':
                    title = elem.text
                elif tname == 'id' and not inrevision:
                    id = int(elem.text)
                elif tname == 'redirect':
                    redirect = elem.attrib['title']
                elif tname == 'ns':
                    ns = int(elem.text)
                elif tname == 'page' and ns == 0:
                    totalCount += 1
                    total_article_text_len += article_text_len                        
                    if len(redirect) == 0:
                        articleCount += 1
                        if len(links) == 0:
                            articlesWriter.writerow([id, title, article_text_len, 0, "", ""])
                        for link in links:
                            articlesWriter.writerow([id, title, article_text_len, link[0], link[1], link[2]])
                    else:
                        redirectCount += 1
                        redirectWriter.writerow([id, title, redirect])

                    if totalCount > 1 and (totalCount % 100000) == 0:
                        print("{:,}".format(totalCount))
                elif tname == 'text' and elem.text != None:
                    article_text_len = len(elem.text)
                    for match in regex_lang.finditer(elem.text):    
                        uk_link = match.group("article")
                    for match in regex_links.finditer(elem.text):    
                        link_pos = match.start()
                        link_title = match.group("article")
                        link_title = link_title.replace("&nbsp;", " ")
                        link_title = link_title.replace("&ndash;", "-")
                        link_title = link_title.replace("&mdash;", "—")
                        link_title = link_title.replace("%20", " ")
                        
                        link_text = match.group("text")
                        links.append((link_pos,link_title,link_text))


                elem.clear()
    
    fn_in = pathArticles
    with open(fn_in, 'rb') as f_in, gzip.open(fn_in+'.gz', 'wb') as f_out:
        f_out.writelines(f_in)
    os.remove(fn_in)
    
    fn_in = pathArticlesRedirect
    with open(fn_in, 'rb') as f_in, gzip.open(fn_in+'.gz', 'wb') as f_out:
        f_out.writelines(f_in)
    os.remove(fn_in)
    
    elapsed_time = time.time() - start_time
    print("File processed: {}".format(WikiXML))
    print("Total pages: {:,}".format(totalCount))
    print("Article pages: {:,}".format(articleCount))
    print("Redirect pages: {:,}".format(redirectCount))
    print("Total article lenght: {:,}".format(total_article_text_len))
    print("Elapsed time: {}".format(hms_string(elapsed_time)))

elapsed_time = time.time() - start_time

print("Total pages: {:,}".format(totalCount))
print("Article pages: {:,}".format(articleCount))
print("Redirect pages: {:,}".format(redirectCount))
print("Total article lenght: {:,}".format(total_article_text_len))
print("Elapsed time: {}".format(hms_string(elapsed_time)))
# Out:
# File processed: enwiki-20180620-pages-meta-current01-p10p30303.xml
# Total pages: 49,652
# Article pages: 38,291
# Redirect pages: 11,361
# Total article lenght: 584,538,815
# Elapsed time: 0:00:58.31
# File processed: enwiki-20180620-pages-meta-current02-p30304p88444.xml
# Total pages: 88,197
# Article pages: 65,129
# Redirect pages: 23,068
# Total article lenght: 1,276,094,074
# Elapsed time: 0:02:21.91
# 100,000
# File processed: enwiki-20180620-pages-meta-current03-p88445p200507.xml
# Total pages: 170,115
# Article pages: 130,653
# Redirect pages: 39,462
# Total article lenght: 2,392,075,343
# Elapsed time: 0:04:49.92
# 200,000
# File processed: enwiki-20180620-pages-meta-current04-p200511p352689.xml
# Total pages: 253,573
# Article pages: 179,768
# Redirect pages: 73,805
# Total article lenght: 3,282,443,066
# Elapsed time: 0:06:59.37
# 300,000
# File processed: enwiki-20180620-pages-meta-current05-p352690p565313.xml
# Total pages: 373,022
# Article pages: 244,761
# Redirect pages: 128,261
# Total article lenght: 4,243,772,308
# Elapsed time: 0:09:20.53
# 400,000
# 500,000
# File processed: enwiki-20180620-pages-meta-current06-p565314p892912.xml
# Total pages: 550,074
# Article pages: 322,961
# Redirect pages: 227,113
# Total article lenght: 5,268,553,043
# Elapsed time: 0:12:04.89
# 600,000
# 700,000
# File processed: enwiki-20180620-pages-meta-current07-p892914p1268691.xml
# Total pages: 718,187
# Article pages: 413,799
# Redirect pages: 304,388
# Total article lenght: 6,293,147,520
# Elapsed time: 0:14:55.26
# 800,000
# 900,000
# File processed: enwiki-20180620-pages-meta-current08-p1268692p1791079.xml
# Total pages: 936,160
# Article pages: 518,911
# Redirect pages: 417,249
# Total article lenght: 7,378,662,910
# Elapsed time: 0:18:30.45
# 1,000,000
# 1,100,000
# File processed: enwiki-20180620-pages-meta-current09-p1791080p2336422.xml
# Total pages: 1,163,471
# Article pages: 625,737
# Redirect pages: 537,734
# Total article lenght: 8,424,560,411
# Elapsed time: 0:21:16.00
# 1,200,000
# 1,300,000
# 1,400,000
# File processed: enwiki-20180620-pages-meta-current10-p2336425p3046511.xml
# Total pages: 1,414,058
# Article pages: 748,900
# Redirect pages: 665,158
# Total article lenght: 9,473,273,537
# Elapsed time: 0:25:36.04
# 1,500,000
# 1,600,000
# File processed: enwiki-20180620-pages-meta-current11-p3046514p3926861.xml
# Total pages: 1,695,960
# Article pages: 882,144
# Redirect pages: 813,816
# Total article lenght: 10,565,017,949
# Elapsed time: 0:29:00.78
# 1,700,000
# 1,800,000
# 1,900,000
# 2,000,000
# File processed: enwiki-20180620-pages-meta-current12-p3926863p5040436.xml
# Total pages: 2,013,363
# Article pages: 1,027,609
# Redirect pages: 985,754
# Total article lenght: 11,679,401,730
# Elapsed time: 0:32:41.85
# 2,100,000
# 2,200,000
# 2,300,000
# File processed: enwiki-20180620-pages-meta-current13-p5040438p6197594.xml
# Total pages: 2,344,455
# Article pages: 1,175,501
# Redirect pages: 1,168,954
# Total article lenght: 12,747,450,418
# Elapsed time: 0:36:22.23
# 2,400,000
# 2,500,000
# 2,600,000
# File processed: enwiki-20180620-pages-meta-current14-p6197598p7697598.xml
# Total pages: 2,697,280
# Article pages: 1,333,082
# Redirect pages: 1,364,198
# Total article lenght: 13,800,819,769
# Elapsed time: 0:40:24.58
# 2,700,000
# File processed: enwiki-20180620-pages-meta-current14-p7697598p7744799.xml
# Total pages: 2,707,389
# Article pages: 1,337,634
# Redirect pages: 1,369,755
# Total article lenght: 13,830,940,055
# Elapsed time: 0:40:33.62
# 2,800,000
# 2,900,000
# 3,000,000
# File processed: enwiki-20180620-pages-meta-current15-p7744803p9244803.xml
# Total pages: 3,043,463
# Article pages: 1,478,272
# Redirect pages: 1,565,191
# Total article lenght: 14,783,726,204
# Elapsed time: 0:44:54.29
# 3,100,000
# File processed: enwiki-20180620-pages-meta-current15-p9244803p9518048.xml
# Total pages: 3,101,053
# Article pages: 1,502,597
# Redirect pages: 1,598,456
# Total article lenght: 14,947,365,270
# Elapsed time: 0:46:08.08
# 3,200,000
# File processed: enwiki-20180620-pages-meta-current16-p11018050p11539266.xml
# Total pages: 3,208,798
# Article pages: 1,548,973
# Redirect pages: 1,659,825
# Total article lenght: 15,247,838,550
# Elapsed time: 0:47:36.94
# 3,300,000
# 3,400,000
# File processed: enwiki-20180620-pages-meta-current16-p9518050p11018050.xml
# Total pages: 3,483,613
# Article pages: 1,668,323
# Redirect pages: 1,815,290
# Total article lenght: 16,038,584,236
# Elapsed time: 0:51:18.90
# 3,500,000
# 3,600,000
# 3,700,000
# 3,800,000
# File processed: enwiki-20180620-pages-meta-current17-p11539268p13039268.xml
# Total pages: 3,870,533
# Article pages: 1,841,036
# Redirect pages: 2,029,497
# Total article lenght: 16,973,390,620
# Elapsed time: 0:55:11.83
# 3,900,000
# 4,000,000
# File processed: enwiki-20180620-pages-meta-current17-p13039268p13693071.xml
# Total pages: 4,023,041
# Article pages: 1,903,725
# Redirect pages: 2,119,316
# Total article lenght: 17,315,259,388
# Elapsed time: 0:57:04.55
# 4,100,000
# 4,200,000
# 4,300,000
# File processed: enwiki-20180620-pages-meta-current18-p13693074p15193074.xml
# Total pages: 4,388,929
# Article pages: 2,039,703
# Redirect pages: 2,349,226
# Total article lenght: 18,151,211,430
# Elapsed time: 1:01:07.95
# 4,400,000
# 4,500,000
# File processed: enwiki-20180620-pages-meta-current18-p15193074p16120542.xml
# Total pages: 4,595,234
# Article pages: 2,137,613
# Redirect pages: 2,457,621
# Total article lenght: 18,626,439,760
# Elapsed time: 1:03:29.62
# 4,600,000
# 4,700,000
# 4,800,000
# 4,900,000
# File processed: enwiki-20180620-pages-meta-current19-p16120543p17620543.xml
# Total pages: 4,987,891
# Article pages: 2,250,001
# Redirect pages: 2,737,890
# Total article lenght: 19,332,147,085
# Elapsed time: 1:08:08.56
# 5,000,000
# 5,100,000
# 5,200,000
# File processed: enwiki-20180620-pages-meta-current19-p17620543p18754735.xml
# Total pages: 5,235,295
# Article pages: 2,357,580
# Redirect pages: 2,877,715
# Total article lenght: 19,921,622,076
# Elapsed time: 1:11:16.17
# 5,300,000
# 5,400,000
# 5,500,000
# File processed: enwiki-20180620-pages-meta-current20-p18754736p20254736.xml
# Total pages: 5,593,855
# Article pages: 2,501,502
# Redirect pages: 3,092,353
# Total article lenght: 20,717,051,113
# Elapsed time: 1:15:12.43
# 5,600,000
# 5,700,000
# File processed: enwiki-20180620-pages-meta-current20-p20254736p21222156.xml
# Total pages: 5,788,900
# Article pages: 2,587,553
# Redirect pages: 3,201,347
# Total article lenght: 21,220,867,597
# Elapsed time: 1:17:55.28
# 5,800,000
# 5,900,000
# 6,000,000
# 6,100,000
# File processed: enwiki-20180620-pages-meta-current21-p21222158p22722158.xml
# Total pages: 6,147,271
# Article pages: 2,742,713
# Redirect pages: 3,404,558
# Total article lenght: 22,037,870,176
# Elapsed time: 1:23:30.11
# 6,200,000
# 6,300,000
# 6,400,000
# File processed: enwiki-20180620-pages-meta-current21-p22722158p23927983.xml
# Total pages: 6,470,798
# Article pages: 2,861,447
# Redirect pages: 3,609,351
# Total article lenght: 22,727,752,347
# Elapsed time: 1:26:51.67
# 6,500,000
# 6,600,000
# 6,700,000
# 6,800,000
# File processed: enwiki-20180620-pages-meta-current22-p23927984p25427984.xml
# Total pages: 6,811,068
# Article pages: 3,005,285
# Redirect pages: 3,805,783
# Total article lenght: 23,566,211,008
# Elapsed time: 1:30:59.54
# 6,900,000
# 7,000,000
# 7,100,000
# File processed: enwiki-20180620-pages-meta-current22-p25427984p26823660.xml
# Total pages: 7,115,281
# Article pages: 3,128,221
# Redirect pages: 3,987,060
# Total article lenght: 24,302,988,455
# Elapsed time: 1:35:05.51
# 7,200,000
# 7,300,000
# 7,400,000
# File processed: enwiki-20180620-pages-meta-current23-p26823661p28323661.xml
# Total pages: 7,476,234
# Article pages: 3,267,295
# Redirect pages: 4,208,939
# Total article lenght: 25,106,918,973
# Elapsed time: 1:38:57.77
# 7,500,000
# 7,600,000
# 7,700,000
# 7,800,000
# File processed: enwiki-20180620-pages-meta-current23-p28323661p29823661.xml
# Total pages: 7,854,733
# Article pages: 3,390,100
# Redirect pages: 4,464,633
# Total article lenght: 25,773,099,345
# Elapsed time: 1:42:41.16
# 7,900,000
# 8,000,000
# File processed: enwiki-20180620-pages-meta-current23-p29823661p30503449.xml
# Total pages: 8,020,944
# Article pages: 3,435,822
# Redirect pages: 4,585,122
# Total article lenght: 26,053,361,042
# Elapsed time: 1:44:32.39
# 8,100,000
# 8,200,000
# 8,300,000
# File processed: enwiki-20180620-pages-meta-current24-p30503451p32003451.xml
# Total pages: 8,356,521
# Article pages: 3,567,841
# Redirect pages: 4,788,680
# Total article lenght: 26,917,061,639
# Elapsed time: 1:48:32.44
# 8,400,000
# 8,500,000
# 8,600,000
# File processed: enwiki-20180620-pages-meta-current24-p32003451p33503451.xml
# Total pages: 8,685,544
# Article pages: 3,697,602
# Redirect pages: 4,987,942
# Total article lenght: 27,696,875,548
# Elapsed time: 1:52:33.88
# 8,700,000
# File processed: enwiki-20180620-pages-meta-current24-p33503451p33952815.xml
# Total pages: 8,780,946
# Article pages: 3,736,996
# Redirect pages: 5,043,950
# Total article lenght: 27,929,477,395
# Elapsed time: 1:53:42.58
# 8,800,000
# 8,900,000
# 9,000,000
# File processed: enwiki-20180620-pages-meta-current25-p33952816p35452816.xml
# Total pages: 9,097,352
# Article pages: 3,850,478
# Redirect pages: 5,246,874
# Total article lenght: 28,612,133,364
# Elapsed time: 1:57:16.95
# 9,100,000
# 9,200,000
# 9,300,000
# 9,400,000
# File processed: enwiki-20180620-pages-meta-current25-p35452816p36952816.xml
# Total pages: 9,462,085
# Article pages: 4,001,675
# Redirect pages: 5,460,410
# Total article lenght: 29,457,358,030
# Elapsed time: 2:01:08.93
# 9,500,000
# 9,600,000
# 9,700,000
# File processed: enwiki-20180620-pages-meta-current25-p36952816p38067202.xml
# Total pages: 9,717,927
# Article pages: 4,097,291
# Redirect pages: 5,620,636
# Total article lenght: 30,032,740,010
# Elapsed time: 2:03:58.09
# 9,800,000
# 9,900,000
# 10,000,000
# File processed: enwiki-20180620-pages-meta-current26-p38067203p39567203.xml
# Total pages: 10,081,286
# Article pages: 4,228,898
# Redirect pages: 5,852,388
# Total article lenght: 30,850,078,384
# Elapsed time: 2:07:46.73
# 10,100,000
# 10,200,000
# 10,300,000
# 10,400,000
# File processed: enwiki-20180620-pages-meta-current26-p39567203p41067203.xml
# Total pages: 10,419,443
# Article pages: 4,369,663
# Redirect pages: 6,049,780
# Total article lenght: 31,691,960,464
# Elapsed time: 2:11:39.05
# 10,500,000
# 10,600,000
# 10,700,000
# File processed: enwiki-20180620-pages-meta-current26-p41067203p42567203.xml
# Total pages: 10,759,035
# Article pages: 4,510,591
# Redirect pages: 6,248,444
# Total article lenght: 32,515,735,202
# Elapsed time: 2:18:19.15
# File processed: enwiki-20180620-pages-meta-current26-p42567203p42663461.xml
# Total pages: 10,780,156
# Article pages: 4,518,999
# Redirect pages: 6,261,157
# Total article lenght: 32,567,509,403
# Elapsed time: 2:18:39.61
# 10,800,000
# 10,900,000
# 11,000,000
# 11,100,000
# File processed: enwiki-20180620-pages-meta-current27-p42663462p44163462.xml
# Total pages: 11,155,887
# Article pages: 4,658,995
# Redirect pages: 6,496,892
# Total article lenght: 33,394,875,528
# Elapsed time: 2:23:27.91
# 11,200,000
# 11,300,000
# 11,400,000
# File processed: enwiki-20180620-pages-meta-current27-p44163462p45663462.xml
# Total pages: 11,441,037
# Article pages: 4,782,371
# Redirect pages: 6,658,666
# Total article lenght: 34,131,725,526
# Elapsed time: 2:27:23.86
# 11,500,000
# 11,600,000
# File processed: enwiki-20180620-pages-meta-current27-p45663462p47163462.xml
# Total pages: 11,677,059
# Article pages: 4,873,028
# Redirect pages: 6,804,031
# Total article lenght: 34,715,266,000
# Elapsed time: 2:32:14.34
# 11,700,000
# 11,800,000
# 11,900,000
# File processed: enwiki-20180620-pages-meta-current27-p47163462p48663462.xml
# Total pages: 11,974,811
# Article pages: 4,988,569
# Redirect pages: 6,986,242
# Total article lenght: 35,427,751,664
# Elapsed time: 2:36:22.63
# 12,000,000
# 12,100,000
# 12,200,000
# 12,300,000
# File processed: enwiki-20180620-pages-meta-current27-p48663462p50163462.xml
# Total pages: 12,344,024
# Article pages: 5,098,081
# Redirect pages: 7,245,943
# Total article lenght: 36,112,970,570
# Elapsed time: 2:41:39.03
# 12,400,000
# 12,500,000
# 12,600,000
# File processed: enwiki-20180620-pages-meta-current27-p50163462p51663462.xml
# Total pages: 12,685,946
# Article pages: 5,220,095
# Redirect pages: 7,465,851
# Total article lenght: 36,859,668,414
# Elapsed time: 2:46:47.65
# 12,700,000
# 12,800,000
# 12,900,000
# File processed: enwiki-20180620-pages-meta-current27-p51663462p53163462.xml
# Total pages: 12,978,662
# Article pages: 5,331,968
# Redirect pages: 7,646,694
# Total article lenght: 37,521,046,837
# Elapsed time: 2:52:28.71
# 13,000,000
# 13,100,000
# 13,200,000
# 13,300,000
# File processed: enwiki-20180620-pages-meta-current27-p53163462p54663462.xml
# Total pages: 13,309,045
# Article pages: 5,452,392
# Redirect pages: 7,856,653
# Total article lenght: 38,239,784,711
# Elapsed time: 2:56:24.67
# 13,400,000
# 13,500,000
# 13,600,000
# File processed: enwiki-20180620-pages-meta-current27-p54663462p56163462.xml
# Total pages: 13,662,296
# Article pages: 5,555,205
# Redirect pages: 8,107,091
# Total article lenght: 38,864,662,227
# Elapsed time: 3:01:30.02
# 13,700,000
# 13,800,000
# 13,900,000
# File processed: enwiki-20180620-pages-meta-current27-p56163462p57663462.xml
# Total pages: 13,997,727
# Article pages: 5,688,457
# Redirect pages: 8,309,270
# Total article lenght: 39,576,523,287
# Elapsed time: 3:07:38.82
# 14,000,000
# File processed: enwiki-20180620-pages-meta-current27-p57663462p57726175.xml
# Total pages: 14,011,889
# Article pages: 5,693,113
# Redirect pages: 8,318,776
# Total article lenght: 39,601,777,350
# Elapsed time: 3:07:55.73
# Total pages: 14,011,889
# Article pages: 5,693,113
# Redirect pages: 8,318,776
# Total article lenght: 39,601,777,350
# Elapsed time: 3:07:55.73
