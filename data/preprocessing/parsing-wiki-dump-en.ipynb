# %%
import xml.etree.ElementTree as etree
import codecs
import csv
import time
import os
import re
import gzip

# %%
PATH_WIKI_XML = 'd:/MMD- Project - Power2TheWiki/data/en/'
PATH_WIKI_OUT = 'd:/MGontar/Storages/Google Drive/20. Data Science/0.UCU Study/Mining Massive Datasets/Project/out/'

# %%
WIKI_FILENAMES = []
for file in os.listdir(PATH_WIKI_XML):
    if file.endswith(".xml"):
        WIKI_FILENAMES.append(file)
        
print(WIKI_FILENAMES.index("enwiki-20180620-pages-meta-current25-p36952816p38067202.xml"))
# Out:
# 39

# %%
ENCODING = "utf-8"


# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)


def strip_tag_name(t):
    t = elem.tag
    idx = k = t.rfind("}")
    if idx != -1:
        t = t[idx + 1:]
    return t


#File processed: enwiki-20180620-pages-meta-current25-p36952816p38067202.xml
#Total pages: 9,687,998
#Article pages: 4,074,048
#Redirect pages: 5,613,950
#Pages with UK link: 683
#Pages with RU link: 0
#Pages with UK and RU link: 0
#Elapsed time: 2:03:15.52
#9,700,000
#9,800,000
#9,900,000

totalCount = 0
articleCount = 0
redirectCount = 0
withUkLinkCount = 0
withRuLinkCount = 0
withUkRuLinkCount = 0
title = None

# %%
start_time = time.time()
regex_links = re.compile(r"\[\[(?P<article>(?!.*?\:).+?)(?:\|(?P<text>.+?))?\]\]")
regex_lang = re.compile(r"\[\[uk\:(?P<article>.+?)\]\]")
regex_lang_ru = re.compile(r"\[\[ru\:(?P<article>.+?)\]\]")
for WikiXML in WIKI_FILENAMES:
    pathWikiXML = os.path.join(PATH_WIKI_XML, WikiXML)
    pathArticles = os.path.join(PATH_WIKI_OUT, WikiXML+"_art.csv")
    pathArticlesRedirect = os.path.join(PATH_WIKI_OUT, WikiXML+"_red.csv")
    with codecs.open(pathArticles, "w", ENCODING) as articlesFH, \
    codecs.open(pathArticlesRedirect, "w", ENCODING) as redirectFH:
        articlesWriter = csv.writer(articlesFH, quoting=csv.QUOTE_MINIMAL)
        articlesWriter.writerow(['id', 'title', 'ua', 'link_pos', 'link_val', 'link_txt']) 
        redirectWriter = csv.writer(redirectFH, quoting=csv.QUOTE_MINIMAL)
        redirectWriter.writerow(['id', 'title', 'redirect'])
        for event, elem in etree.iterparse(pathWikiXML, events=('start', 'end')):
            tname = strip_tag_name(elem.tag)

            if event == 'start':
                if tname == 'page':
                    title = ''
                    id = -1
                    redirect = ''
                    inrevision = False
                    ns = 0
                    txtlen = 0
                    uk_link = ''
                    ru_link = ''
                    links = []
                elif tname == 'revision':
                    # Do not pick up on revision id's
                    inrevision = True
            else:
                if tname == 'title':
                    title = elem.text
                elif tname == 'id' and not inrevision:
                    id = int(elem.text)
                elif tname == 'redirect':
                    redirect = elem.attrib['title']
                elif tname == 'ns':
                    ns = int(elem.text)
                elif tname == 'page' and ns == 0:
                    totalCount += 1
                    if len(uk_link) > 0:
                        withUkLinkCount += 1
                    if len(ru_link) > 0:
                        withRuLinkCount += 1  
                    if len(uk_link) > 0 and len(ru_link) > 0:
                        withUkRuLinkCount += 1
                        
                    if len(redirect) == 0:
                        articleCount += 1
                        if len(links) == 0:
                            articlesWriter.writerow([id, title, uk_link, "", "", ""])
                        for link in links:
                            articlesWriter.writerow([id, title, uk_link, link[0], link[1], link[2]])
                    else:
                        redirectCount += 1
                        redirectWriter.writerow([id, title, redirect])

                    if totalCount > 1 and (totalCount % 100000) == 0:
                        print("{:,}".format(totalCount))
                elif tname == 'text' and elem.text != None:
                    txtlen = len(elem.text)
                    for match in regex_lang.finditer(elem.text):    
                        uk_link = match.group("article")
                    for match in regex_links.finditer(elem.text):    
                        link_pos = match.start()
                        link_title = match.group("article")
                        link_text = match.group("text")
                        links.append((link_pos,link_title,link_text))


                elem.clear()
    
    fn_in = pathArticles
    with open(fn_in, 'rb') as f_in, gzip.open(fn_in+'.gz', 'wb') as f_out:
        f_out.writelines(f_in)
    os.remove(fn_in)
    
    fn_in = pathArticlesRedirect
    with open(fn_in, 'rb') as f_in, gzip.open(fn_in+'.gz', 'wb') as f_out:
        f_out.writelines(f_in)
    os.remove(fn_in)
    
    elapsed_time = time.time() - start_time
    print("File processed: {}".format(WikiXML))
    print("Total pages: {:,}".format(totalCount))
    print("Article pages: {:,}".format(articleCount))
    print("Redirect pages: {:,}".format(redirectCount))
    print("Pages with UK link: {:,}".format(withUkLinkCount))
    print("Pages with RU link: {:,}".format(withRuLinkCount))
    print("Pages with UK and RU link: {:,}".format(withUkRuLinkCount))
    print("Elapsed time: {}".format(hms_string(elapsed_time)))

elapsed_time = time.time() - start_time

print("Total pages: {:,}".format(totalCount))
print("Article pages: {:,}".format(articleCount))
print("Redirect pages: {:,}".format(redirectCount))
print("Pages with UK link: {:,}".format(withUkLinkCount))
print("Pages with RU link: {:,}".format(withRuLinkCount))
print("Pages with UK and RU link: {:,}".format(withUkRuLinkCount))
print("Elapsed time: {}".format(hms_string(elapsed_time)))
# Out:
# 9,700,000
# 9,800,000
# 9,900,000
# 10,000,000
# File processed: enwiki-20180620-pages-meta-current26-p38067203p39567203.xml
# Total pages: 10,051,357
# Article pages: 4,205,655
# Redirect pages: 5,845,702
# Pages with UK link: 692
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:04:04.04
# 10,100,000
# 10,200,000
# 10,300,000
# File processed: enwiki-20180620-pages-meta-current26-p39567203p41067203.xml
# Total pages: 10,389,514
# Article pages: 4,346,420
# Redirect pages: 6,043,094
# Pages with UK link: 693
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:08:03.00
# 10,400,000
# 10,500,000
# 10,600,000
# 10,700,000
# File processed: enwiki-20180620-pages-meta-current26-p41067203p42567203.xml
# Total pages: 10,729,106
# Article pages: 4,487,348
# Redirect pages: 6,241,758
# Pages with UK link: 697
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:12:52.91
# File processed: enwiki-20180620-pages-meta-current26-p42567203p42663461.xml
# Total pages: 10,750,227
# Article pages: 4,495,756
# Redirect pages: 6,254,471
# Pages with UK link: 697
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:13:15.92
# 10,800,000
# 10,900,000
# 11,000,000
# 11,100,000
# File processed: enwiki-20180620-pages-meta-current27-p42663462p44163462.xml
# Total pages: 11,125,958
# Article pages: 4,635,752
# Redirect pages: 6,490,206
# Pages with UK link: 697
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:18:10.60
# 11,200,000
# 11,300,000
# 11,400,000
# File processed: enwiki-20180620-pages-meta-current27-p44163462p45663462.xml
# Total pages: 11,411,108
# Article pages: 4,759,128
# Redirect pages: 6,651,980
# Pages with UK link: 704
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:22:31.23
# 11,500,000
# 11,600,000
# File processed: enwiki-20180620-pages-meta-current27-p45663462p47163462.xml
# Total pages: 11,647,130
# Article pages: 4,849,785
# Redirect pages: 6,797,345
# Pages with UK link: 707
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:26:37.37
# 11,700,000
# 11,800,000
# 11,900,000
# File processed: enwiki-20180620-pages-meta-current27-p47163462p48663462.xml
# Total pages: 11,944,882
# Article pages: 4,965,326
# Redirect pages: 6,979,556
# Pages with UK link: 710
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:30:11.96
# 12,000,000
# 12,100,000
# 12,200,000
# 12,300,000
# File processed: enwiki-20180620-pages-meta-current27-p48663462p50163462.xml
# Total pages: 12,314,095
# Article pages: 5,074,838
# Redirect pages: 7,239,257
# Pages with UK link: 713
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:33:51.93
# 12,400,000
# 12,500,000
# 12,600,000
# File processed: enwiki-20180620-pages-meta-current27-p50163462p51663462.xml
# Total pages: 12,656,017
# Article pages: 5,196,852
# Redirect pages: 7,459,165
# Pages with UK link: 713
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:38:31.06
# 12,700,000
# 12,800,000
# 12,900,000
# File processed: enwiki-20180620-pages-meta-current27-p51663462p53163462.xml
# Total pages: 12,948,733
# Article pages: 5,308,725
# Redirect pages: 7,640,008
# Pages with UK link: 713
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:43:50.37
# 13,000,000
# 13,100,000
# 13,200,000
# File processed: enwiki-20180620-pages-meta-current27-p53163462p54663462.xml
# Total pages: 13,279,116
# Article pages: 5,429,149
# Redirect pages: 7,849,967
# Pages with UK link: 713
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:47:26.55
# 13,300,000
# 13,400,000
# 13,500,000
# 13,600,000
# File processed: enwiki-20180620-pages-meta-current27-p54663462p56163462.xml
# Total pages: 13,632,367
# Article pages: 5,531,962
# Redirect pages: 8,100,405
# Pages with UK link: 714
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:51:01.76
# 13,700,000
# 13,800,000
# 13,900,000
# File processed: enwiki-20180620-pages-meta-current27-p56163462p57663462.xml
# Total pages: 13,967,798
# Article pages: 5,665,214
# Redirect pages: 8,302,584
# Pages with UK link: 715
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:54:37.75
# File processed: enwiki-20180620-pages-meta-current27-p57663462p57726175.xml
# Total pages: 13,981,960
# Article pages: 5,669,870
# Redirect pages: 8,312,090
# Pages with UK link: 715
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:54:49.19
# Total pages: 13,981,960
# Article pages: 5,669,870
# Redirect pages: 8,312,090
# Pages with UK link: 715
# Pages with RU link: 0
# Pages with UK and RU link: 0
# Elapsed time: 0:54:49.19
